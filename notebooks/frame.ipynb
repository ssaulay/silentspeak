# %%
from matplotlib import pyplot as plt
import os
import cv2
import tensorflow as tf
import numpy as np

# %%
from typing import List

# %%
def load_video(path:str) -> List[float]: 

    cap = cv2.VideoCapture(path)
    frames = []
    for _ in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))): 
        ret, frame = cap.read()
        frame = tf.image.rgb_to_grayscale(frame)
        frames.append(frame)
    cap.release()
    return frames

# %%
frames = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session I/Locuteur_I_1/videos/1_front - 0.avi")

# %%
frames
# Out:
# [<tf.Tensor: shape=(576, 720, 1), dtype=uint8, numpy=
#  array([[[47],
#          [53],
#          [42],
#          ...,
#          [48],
#          [51],
#          [42]],
#
#         [[49],
#          [49],
#          [50],
#          ...,
#          [47],
#          [49],
#          [41]],
#
#         [[53],
#          [53],
#          [48],
#          ...,
#          [47],
#          [47],
#          [42]],
#
#         ...,
#
#         [[13],
#          [17],
#          [15],
#          ...,
#          [ 0],
#          [ 0],
#          [ 0]],
#
#         [[11],
#          [18],
#          [17],
#          ...,
#          [ 0],
#          [ 0],
#          [ 0]],
#
#         [[11],
#          [15],
#          [15],
#          ...,
#          [ 0],
#          [ 0],
#          [ 0]]], dtype=uint8)>,
#  <tf.Tensor: shape=(576, 720, 1), dtype=uint8, numpy=
#  array([[[51],
#          [49],
#          [47],
#          ...,
#          [51],
#          [52],
#          [49]],
#
# ...

# %%
#frame[hauteur, largeur, channel(=1)]

# %%
from matplotlib.patches import Rectangle

# %%
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames[25], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
plt.imshow(frames[25][350:500,230:530,:])

# %%
frames_2 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session I/Locuteur_I_2/videos/2_front - 0.avi")

# %%
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_2[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_3 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session I/Locuteur_I_3/vidǸos/4_front.avi")

# %%
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_3[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_4 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session I/Locuteur_I_4/videos/4_front.avi")

# %%
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_4[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_5 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session I/Locuteur_I_5/videos/4_front.avi")

# %%
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_5[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_6 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session I/Locuteur_I_6/videos/4_front.avi")

# %%
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_6[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_7 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session I/Locuteur_I_7/videos/4_front - 0.avi")

# %%
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_7[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_8 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session I/Locuteur_I_8/videos/16_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_8[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_9 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session II/Locuteur_II_1/videos/137_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_9[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_10 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session II/Locuteur_II_2/videos/137_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_10[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_11 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session II/Locuteur_II_3/videos/130_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_11[20], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_12 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session II/Locuteur_II_4/videos/130_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_12[20], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_13 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session II/Locuteur_II_5/videos/130_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_13[20], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_14 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session II/Locuteur_II_6/videos/130_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_14[20], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_15 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session II/Locuteur_II_7/videos/130_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_15[20], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()

# %%
frames_16 = load_video("/Users/mac/code/ssaulay/silentspeak/raw_data/Session II/Locuteur_II_8/videos/130_front - 0.avi")
fig = plt.figure() 
ax=plt.gca()
ax.imshow(frames_16[1], cmap="gray")

rec = Rectangle(
    xy = (230, 350),
    width=300,
    height=150,
    alpha = 0.5

)

ax.add_patch(rec)

plt.show()
