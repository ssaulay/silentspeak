# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

# %%
from process_video import load_video, get_phonems, load_data

# %%
path = "/Users/ArthurPech/Downloads/SilentSpeak/"
session = 'I'
locutor = 1
file = 1

# %%
frames, phonems = load_data(path, session, locutor, file)

# %%
frames
# Out:
# [<tf.Tensor: shape=(576, 720, 1), dtype=uint8, numpy=
#  array([[[57],
#          [60],
#          [52],
#          ...,
#          [57],
#          [60],
#          [53]],
#
#         [[53],
#          [59],
#          [57],
#          ...,
#          [55],
#          [56],
#          [54]],
#
#         [[59],
#          [61],
#          [58],
#          ...,
#          [57],
#          [58],
#          [53]],
#
#         ...,
#
#         [[28],
#          [31],
#          [29],
#          ...,
#          [16],
#          [16],
#          [15]],
#
#         [[27],
#          [31],
#          [29],
#          ...,
#          [15],
#          [15],
#          [11]],
#
#         [[25],
#          [26],
#          [29],
#          ...,
#          [13],
#          [15],
#          [13]]], dtype=uint8)>,
#  <tf.Tensor: shape=(576, 720, 1), dtype=uint8, numpy=
#  array([[[57],
#          [59],
#          [59],
#          ...,
#          [59],
#          [58],
#          [55]],
#
# ...

# %%
phonems
# Out:
# ['m', 'a', 'S', 'deux', 'm', 'i', 'z', 'E', 'R', 'u', 's', 'i']
