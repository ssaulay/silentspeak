# %%
import cv2
import mediapipe as mp

# %%
# Initializing the drawing utils for drawing the facial landmarks on image
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)
with mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    min_detection_confidence=0.5) as face_mesh:
    
    image = cv2.imread("/home/clement/code/ssaulay/silentspeak/raw_data/BL-Database/test2.png")
    
    results = face_mesh.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if not results.multi_face_landmarks:
        print('continue')
    annotated_image = image.copy()
    for face_landmarks in results.multi_face_landmarks:
        print('face_landmarks', face_landmarks)
        mp_drawing.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=drawing_spec,
            connection_drawing_spec=drawing_spec)
                
        cv2.imwrite(r'mesh.png', annotated_image)
# Out:
# face_landmarks landmark {
#   x: 0.5223720669746399
#   y: 0.7937771081924438
#   z: -0.056739192456007004
# }
# landmark {
#   x: 0.5260056257247925
#   y: 0.6890603303909302
#   z: -0.17240650951862335
# }
# landmark {
#   x: 0.5230688452720642
#   y: 0.7086590528488159
#   z: -0.07204391062259674
# }
# landmark {
#   x: 0.49503806233406067
#   y: 0.565147340297699
#   z: -0.1582709401845932
# }
# landmark {
#   x: 0.5264219045639038
#   y: 0.6567738652229309
#   z: -0.1917729526758194
# }
# landmark {
#   x: 0.526039183139801
#   y: 0.6065384745597839
#   z: -0.18973390758037567
# }
# landmark {
#   x: 0.5237100124359131
#   y: 0.4712459444999695
#   z: -0.13533493876457214
# }
# landmark {
#   x: 0.2704325318336487
#   y: 0.432900607585907
#   z: -0.0108852069824934
# }
# landmark {
#   x: 0.5228960514068604
#   y: 0.3743412494659424
#   z: -0.14016003906726837
# }
# landmark {
#   x: 0.5223401188850403
#   y: 0.3261832594871521
#   z: -0.16255442798137665
# }
# landmark {
# ...

# %%
# Initializing the drawing utils for drawing the facial landmarks on image
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)
with mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    min_detection_confidence=0.5) as face_mesh:

    image = cv2.imread("/home/clement/code/ssaulay/silentspeak/raw_data/BL-Database/test.png")

    results = face_mesh.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if not results.multi_face_landmarks:
        print('continue')
    annotated_image = image.copy()
    for face_landmarks in results.multi_face_landmarks:
        print('face_landmarks', face_landmarks)
        for idx, landmark in enumerate(face_landmarks.landmark):
            x = int(landmark.x * image.shape[1])
            y = int(landmark.y * image.shape[0])
            cv2.putText(annotated_image, str(idx), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.25, (0, 0, 0), 1, cv2.LINE_AA)
        
        mp_drawing.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=drawing_spec,
            connection_drawing_spec=drawing_spec)
                
        cv2.imwrite(r'mesh.png', annotated_image)
# Out:
# face_landmarks landmark {
#   x: 0.49292436242103577
#   y: 0.6861734986305237
#   z: -0.03853340446949005
# }
# landmark {
#   x: 0.49530428647994995
#   y: 0.6350147128105164
#   z: -0.11020377278327942
# }
# landmark {
#   x: 0.4934822618961334
#   y: 0.6457735896110535
#   z: -0.04819397255778313
# }
# landmark {
#   x: 0.47511783242225647
#   y: 0.5693204402923584
#   z: -0.09848979860544205
# }
# landmark {
#   x: 0.4951562285423279
#   y: 0.6174784898757935
#   z: -0.12162453681230545
# }
# landmark {
#   x: 0.49454477429389954
#   y: 0.5908436179161072
#   z: -0.11921437084674835
# }
# landmark {
#   x: 0.4921705424785614
#   y: 0.5198585987091064
#   z: -0.08220567554235458
# }
# landmark {
#   x: 0.334369421005249
#   y: 0.5016648769378662
#   z: -0.002673523500561714
# }
# landmark {
#   x: 0.4907582104206085
#   y: 0.4699898958206177
#   z: -0.08291342109441757
# }
# landmark {
#   x: 0.4899213910102844
#   y: 0.4449406862258911
#   z: -0.0955234244465828
# }
# ...

# %%
import numpy as np

# %%
# Initializing the drawing utils for drawing the facial landmarks on image
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)
with mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    min_detection_confidence=0.5) as face_mesh:

    image = cv2.imread("/home/clement/code/ssaulay/silentspeak/raw_data/BL-Database/test2.png")

    results = face_mesh.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if not results.multi_face_landmarks:
        print('continue')
    annotated_image = image.copy()
    for face_landmarks in results.multi_face_landmarks:
        print('face_landmarks', face_landmarks)
        for idx, landmark in enumerate(face_landmarks.landmark):
            x = int(landmark.x * image.shape[1])
            y = int(landmark.y * image.shape[0])
            cv2.putText(annotated_image, str(idx), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.25, (0, 0, 0), 1, cv2.LINE_AA)
        
        mp_drawing.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=drawing_spec,
            connection_drawing_spec=drawing_spec)
                
        cv2.imwrite(r'mesh2.png', annotated_image)
# Out:
# face_landmarks landmark {
#   x: 0.5223720669746399
#   y: 0.7937771081924438
#   z: -0.056739192456007004
# }
# landmark {
#   x: 0.5260056257247925
#   y: 0.6890603303909302
#   z: -0.17240650951862335
# }
# landmark {
#   x: 0.5230688452720642
#   y: 0.7086590528488159
#   z: -0.07204391062259674
# }
# landmark {
#   x: 0.49503806233406067
#   y: 0.565147340297699
#   z: -0.1582709401845932
# }
# landmark {
#   x: 0.5264219045639038
#   y: 0.6567738652229309
#   z: -0.1917729526758194
# }
# landmark {
#   x: 0.526039183139801
#   y: 0.6065384745597839
#   z: -0.18973390758037567
# }
# landmark {
#   x: 0.5237100124359131
#   y: 0.4712459444999695
#   z: -0.13533493876457214
# }
# landmark {
#   x: 0.2704325318336487
#   y: 0.432900607585907
#   z: -0.0108852069824934
# }
# landmark {
#   x: 0.5228960514068604
#   y: 0.3743412494659424
#   z: -0.14016003906726837
# }
# landmark {
#   x: 0.5223401188850403
#   y: 0.3261832594871521
#   z: -0.16255442798137665
# }
# landmark {
# ...

# %%
# Initializing the drawing utils for drawing the facial landmarks on image
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)
with mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    min_detection_confidence=0.5) as face_mesh:

    image = cv2.imread("/home/clement/code/ssaulay/silentspeak/raw_data/BL-Database/test3.png")

    results = face_mesh.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if not results.multi_face_landmarks:
        print('continue')
    annotated_image = image.copy()
    for face_landmarks in results.multi_face_landmarks:
        print('face_landmarks', face_landmarks)
        for idx, landmark in enumerate(face_landmarks.landmark):
            x = int(landmark.x * image.shape[1])
            y = int(landmark.y * image.shape[0])
            cv2.putText(annotated_image, str(idx), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.25, (0, 0, 0), 1, cv2.LINE_AA)
        
        mp_drawing.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=drawing_spec,
            connection_drawing_spec=drawing_spec)
                
        cv2.imwrite(r'mesh3.png', annotated_image)
# Out:
# face_landmarks landmark {
#   x: 0.5094661116600037
#   y: 0.7717836499214172
#   z: -0.07765645533800125
# }
# landmark {
#   x: 0.5115658044815063
#   y: 0.6307950019836426
#   z: -0.23675867915153503
# }
# landmark {
#   x: 0.5102918744087219
#   y: 0.6573710441589355
#   z: -0.10026427358388901
# }
# landmark {
#   x: 0.4705561101436615
#   y: 0.4667147696018219
#   z: -0.21671868860721588
# }
# landmark {
#   x: 0.512003481388092
#   y: 0.5884333252906799
#   z: -0.2632600963115692
# }
# landmark {
#   x: 0.5124307870864868
#   y: 0.5223673582077026
#   z: -0.2601950466632843
# }
# landmark {
#   x: 0.5127676129341125
#   y: 0.34076976776123047
#   z: -0.1839013695716858
# }
# landmark {
#   x: 0.1627781093120575
#   y: 0.28645601868629456
#   z: -0.010180085897445679
# }
# landmark {
#   x: 0.5122830867767334
#   y: 0.2032151222229004
#   z: -0.1877935230731964
# }
# landmark {
#   x: 0.5114132165908813
#   y: 0.13845673203468323
#   z: -0.21763494610786438
# }
# landmark {
# ...

# %%
# Initializing the drawing utils for drawing the facial landmarks on image
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)
with mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    min_detection_confidence=0.5) as face_mesh:

    image = cv2.imread("/home/clement/code/ssaulay/silentspeak/raw_data/BL-Database/test4.png")

    results = face_mesh.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if not results.multi_face_landmarks:
        print('continue')
    annotated_image = image.copy()
    for face_landmarks in results.multi_face_landmarks:
        print('face_landmarks', face_landmarks)
        for idx, landmark in enumerate(face_landmarks.landmark):
            x = int(landmark.x * image.shape[1])
            y = int(landmark.y * image.shape[0])
            cv2.putText(annotated_image, str(idx), (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.3, (0, 0, 0), 1, cv2.LINE_AA)
        
        mp_drawing.draw_landmarks(
            image=annotated_image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=drawing_spec,
            connection_drawing_spec=drawing_spec)
                
        cv2.imwrite(r'mesh4.png', annotated_image)
# Out:
# face_landmarks landmark {
#   x: 0.5089885592460632
#   y: 0.7116333246231079
#   z: -0.08442195504903793
# }
# landmark {
#   x: 0.5133396983146667
#   y: 0.5198711156845093
#   z: -0.2320852428674698
# }
# landmark {
#   x: 0.5098764300346375
#   y: 0.5583406686782837
#   z: -0.1001381054520607
# }
# landmark {
#   x: 0.47289910912513733
#   y: 0.3119094967842102
#   z: -0.2101527750492096
# }
# landmark {
#   x: 0.514585018157959
#   y: 0.46498093008995056
#   z: -0.25725165009498596
# }
# landmark {
#   x: 0.5149236917495728
#   y: 0.3812028467655182
#   z: -0.25264209508895874
# }
# landmark {
#   x: 0.5139115452766418
#   y: 0.15121164917945862
#   z: -0.17170000076293945
# }
# landmark {
#   x: 0.16237103939056396
#   y: 0.0902675986289978
#   z: -0.014872554689645767
# }
# landmark {
#   x: 0.5136875510215759
#   y: -0.03377869725227356
#   z: -0.1707509607076645
# }
# landmark {
#   x: 0.5143887400627136
#   y: -0.1185484528541565
#   z: -0.19728142023086548
# }
# ...

# %%
# Initializing the drawing utils for drawing the facial landmarks on image
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

drawing_spec = mp_drawing.DrawingSpec(thickness=1, circle_radius=1)
with mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    min_detection_confidence=0.5) as face_mesh:

    image = cv2.imread("/home/clement/code/ssaulay/silentspeak/raw_data/BL-Database/test.png")

    results = face_mesh.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if not results.multi_face_landmarks:
        print('continue')
    
    # Create a mask to isolate the mouth region
    mask = np.zeros(image.shape[:2], dtype=np.uint8)
    
    # Mouth landmarks IDs
    mouth_ids = [
        0, 267, 269, 270, 409, 291, 375, 321, 405, 314,
        17, 84, 181, 91, 146, 61, 185, 40, 39, 37, 0,
        13, 312, 311, 310, 415, 308, 324, 318, 402, 317,
        14, 87, 178, 88, 95, 78, 191, 80, 81, 82, 13
    ]
    
    for face_landmarks in results.multi_face_landmarks:
        # Extract the mouth landmarks based on the provided IDs
        mouth_landmarks = [face_landmarks.landmark[idx] for idx in mouth_ids]
        
        # Convert the mouth landmarks to pixel coordinates
        mouth_points = []
        for landmark in mouth_landmarks:
            x = int(landmark.x * image.shape[1])
            y = int(landmark.y * image.shape[0])
            mouth_points.append([x, y])
        
        # Create a contour from the mouth points and fill it in the mask
        cv2.drawContours(mask, [np.array(mouth_points)], 0, (255), -1)
        
        mp_drawing.draw_landmarks(
            image=image,
            landmark_list=face_landmarks,
            connections=mp_face_mesh.FACEMESH_CONTOURS,
            landmark_drawing_spec=drawing_spec,
            connection_drawing_spec=drawing_spec)
                
    # Apply the mask to the original image to isolate the mouth region
    isolated_mouth = cv2.bitwise_and(image, image, mask=mask)

    cv2.imwrite(r'isolated_mouth.png', isolated_mouth)
